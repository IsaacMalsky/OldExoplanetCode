# %%
############################################
########     Planet Composition    #########
############################################


#Import a bunch of stuff
import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[22.2]
enFracList=[.032,.033,.034,.035,.036,.037,.038,.039,.04,.05,.06,.07,.08,.09,.1,.2,.3]
entropyList=[8.0]
yList = [.18,.24,.30]
zList = [.02]
oribitalList=[.05,.1]

mpList=[22.2]
enFracList=[.035]
entropyList=[8.0]
yList = [.24]
zList = [.02]
oribitalList=[.05]

#Iterate again over all the files
numlogs = 0
base_path = "/Users/mmalsky/Desktop/EnvelopeLogs/"
mass_rad_dict = {}
for a in range (0 ,len(enFracList)):
    enFrac = enFracList[a]
    for b in range (0 ,len(entropyList)):
        entropy = entropyList[b]
        for c in range (0 ,len(yList)):
            yfrac = yList[c]
            for d in range (0 ,len(zList)):
                zfrac = zList[d]
                for e in range (0 ,len(oribitalList)):
                    orb_sep = oribitalList[e]
                    for f in range(len(mpList)):
                        myfile = ''
                        mp = mpList[f]
  
                        extension = "{}_{}_{}_{}_{}_{}".format(mp,enFrac,entropy,yfrac,zfrac,orb_sep)
                        myfile = base_path + extension

                        if (os.path.isfile(myfile)):
                            age, hydrogen, helium, c12, n14, o16, ne20 = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,12,14,15,16,17,18])
                            age = (10 ** age)
                            array_type = str(type(age))   
                            
                            if (array_type == "<type 'numpy.ndarray'>"):
                                if (max(age) > 9) :
                                    #plt.plot(age, hydrogen, '#ac86a8', label = 'Hydrogen Fraction')
                                    #plt.plot(age, helium + hydrogen, '#533cc6', label = 'Helium Fraction')
                                    
                                    plt.fill_between(age, 0, hydrogen, facecolor='#ac86a8', alpha = .5, interpolate=True, label = 'Hydrogen')
                                    plt.fill_between(age, hydrogen,hydrogen + helium , facecolor='#533cc6', alpha = .5, interpolate=True,label = 'Helium')
                                    plt.fill_between(age,hydrogen + helium,1 , facecolor='#9e003a', alpha = .5, interpolate=True, label = 'Metals')
plt.xscale('log')                                    
plt.xlabel('Planet Age (Years)', fontsize = 10)
plt.ylabel('Fraction of total envelope mass',fontsize = 10)
plt.title('Planet Composition Evolution')
plt.legend(bbox_to_anchor=(1.0, .23))
plt.axis([5e6, 1e10,0, 1])

#plt.savefig('/Users/mmalsky/Desktop/Composition.png',dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [5000000.0, 10000000000.0, 0, 1]

# %%
############################################
########         Age Radius        #########
############################################




import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[22.2]
enFracList=[.04,.05,.06,.07,.08,.09,.1]
entropyList=[8.0]
yList = [.18,.24,.30]
zList = [.02]
oribitalList=[.05,.1]

#Iterate again over all the files
numlogs = 0
base_path = "/Users/mmalsky/Desktop/EnvelopeLogs/"
mass_rad_dict = {}
for a in range (0 ,len(enFracList)):
    enFrac = enFracList[a]
    for b in range (0 ,len(entropyList)):
        entropy = entropyList[b]
        for c in range (0 ,len(yList)):
            yfrac = yList[c]
            for d in range (0 ,len(zList)):
                zfrac = zList[d]
                for e in range (0 ,len(oribitalList)):
                    orb_sep = oribitalList[e]
                    for f in range(len(mpList)):
                        myfile = ''
                        mp = mpList[f]
                        
                        extension = "{}_{}_{}_{}_{}_{}".format(mp,enFrac,entropy,yfrac,zfrac,orb_sep)
                        myfile = base_path + extension
                        
                        if (os.path.isfile(myfile)):
                            x, y = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,4])
                            x = 10**x
                            y = y / (637.1 * 10 ** 6)
                            array_type = str(type(x))

                            if (array_type == "<type 'numpy.ndarray'>"):
                                if (max(x) > 9) :   
                                    if (orb_sep == .05):
                                        plt.plot(x, y, 'b', label = '')
                                    if (orb_sep == .1):
                                        plt.plot(x, y, 'g')


plt.plot(x, y, 'b', label = 'Orbital Separation of .05 AU')                                           
plt.plot(x, y, 'g', label = 'Orbital Separation of .10 AU')                                        
                                        
plt.xlabel('Planet Age $(Years)$', fontsize = 10)
plt.ylabel('Radius $R_\oplus$', fontsize = 10)
plt.title('Planet Evolution', fontsize = 12)
plt.legend()
plt.xscale('log')
plt.axis([1.15e7, 1e10,2, 3.5])
#plt.savefig('/Users/mmalsky/Desktop/Age.png',dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [11500000.0, 10000000000.0, 2, 3.5]

# %%
###############################################
########     Envelope Composition     #########
###############################################




import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[22.2]
enFracList=[.032,.033,.034,.035,.036,.037,.038,.039,.04,.05,.06,.07,.08,.09,.1,.2,.3]
entropyList=[8.0]
yList = [.18,.24,.30]
zList = [.02]
orbitalList=[.05,.1]

#Iterate again over all the files
numlogs = 0
base_path = "/Users/mmalsky/Desktop/EnvelopeLogs/"
mass_rad_dict = {}
for a in range (0 ,len(mpList)):
    mp = mpList[a]
    for b in range (0 ,len(entropyList)):
        entropy = entropyList[b]
        for c in range (0 ,len(yList)):
            yfrac = yList[c]
            for d in range (0 ,len(zList)):
                zfrac = zList[d]
                for e in range (0 ,len(orbitalList)):
                    orb_sep = oribitalList[e]
                    
                    envelope_list = []
                    hydrogen_list = [] 
                    helium_list = []
                    
                    for f in range(len(enFracList)):
                        myfile = ''
                        enFrac = enFracList[f]

                        extension = "{}_{}_{}_{}_{}_{}".format(mp,enFrac,entropy,yfrac,zfrac,orb_sep)
                        myfile = base_path + extension

                        if (os.path.isfile(myfile)):
                            age, hydrogen, helium = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,12,14])
                            array_type = str(type(age))
                            
                            if (array_type == "<type 'numpy.ndarray'>"):
                                if (max(age) > 9):
                                    mass_rad_dict[myfile] = [age,hydrogen]
                                    envelope_list.append(enFrac)
                                    hydrogen_list.append(hydrogen[-1])
                                    helium_list.append(helium[-1])

                    
                    if (len(envelope_list) > 2):
                        h_function = interp1d(envelope_list,hydrogen_list, kind='quadratic', fill_value = 'extrapolate')
                        he_function = interp1d(envelope_list,helium_list, kind='quadratic', fill_value = 'extrapolate')
                        
                        
                        x_new = np.linspace(min(envelope_list), max(envelope_list), num=5000, endpoint=True)
                        extra = np.linspace(0, .5, num=5000, endpoint=True)
                        
                        if yfrac == .18:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'b', label = 'Initial He of .18')
                        if yfrac == .24:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'g', label = 'Initial He of .24')
                        if yfrac == .30:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'y', label = 'Initial He of .30')
                        
                        #plt.plot(extra, he_function(extra), 'k:', label = '')
                        #plt.plot(x_new, he_function(x_new), 'g', label = '')
                        
                    
                        #plt.plot(extra, (1 - he_function(extra) - h_function(extra)), 'r', label = '')
                        #ax1.fill_between(extra, h_function(extra), facecolor="#CC6666", alpha=.7)
                        
                            
                        
                        
                     
                        
plt.xlabel('Envelope Mass Fraction')
plt.ylabel('Fractional abundance in atmosphere')
plt.title('Atmospheric Escape')
plt.axis([0, .15, 0, 1])   
plt.legend()
                                    
#plt.savefig('/Users/mmalsky/Desktop/HydrogenVariation.png',dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
###############################################
########     Mass Radius Relation     #########
###############################################





import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[5,7.5,10,12.5,15,17.5,20]
enFracList=[.01,.05,.1,.25,.5]
entropyList=[8.0]
#yList = [.18,.20,.22,.24,.26,.28]
yList = [.24]
zList = [.02]
orbitalList=[.5]

#Grab and graph the core radius as a function of planet mass
observed_Mcore, observed_Rcore = loadtxt('/Users/mmalsky/Desktop/Exoplanets-master/coreMRcomp2_v40_all.txt', unpack=True, skiprows =11, usecols=[0,1])
core_radius_function = interp1d(observed_Mcore,observed_Rcore)
core_domain = np.linspace(min(observed_Mcore), max(observed_Mcore), num=500, endpoint=True)
plt.plot(core_domain, core_radius_function(core_domain), 'k--', label = '')

#Iterate again over all the files
numlogs = 0
base_path = '/Users/mmalsky/Desktop/NoMassLoss/LOGS/'
mass_rad_dict = {}
for a in range (0 ,len(enFracList)):
    enFrac = enFracList[a]
    for b in range (0 ,len(entropyList)):
        entropy = entropyList[b]
        for c in range (0 ,len(yList)):
            yfrac = yList[c]
            for d in range (0 ,len(zList)):
                zfrac = zList[d]
                for e in range (0 ,len(orbitalList)):
                    orb_sep = orbitalList[e]
                    
                    r_list = []
                    m_list = []                  

                    for f in range(len(mpList)):
                        myfile = ''
                        mp = mpList[f]
                        
                        extension = "{}_{}_{}_{}_{}_{}".format(mp,enFrac,entropy,yfrac,zfrac,orb_sep)
                        myfile = base_path + extension                        
                        
                        
                        if (os.path.isfile(myfile)):
                            x, y = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,4])
                            y = y / (637.1 * 10 ** 6)
                            array_type = str(type(x))

                            if (array_type == "<type 'numpy.ndarray'>"):
                                if (max(x) > 9) :
                                    mass_rad_dict[myfile] = [x,y]
                                    m_list.append(mp)
                                    r_list.append(y[-1])

                    if (len(m_list) > 3):
                        radius_function = interp1d(m_list,r_list, kind='cubic',fill_value='extrapolate')
                        x_new = np.linspace(min(m_list), max(m_list), num=5000, endpoint=True)
                        extra = np.linspace(0, 20, num=5000, endpoint=True)
                        
                        if (enFrac == .01):
                            plt.plot(x_new, radius_function(x_new),'#0504aa', alpha = 1, label = 'Initial Envelope Fraction of 1%')
                        if (enFrac == .05):
                            plt.plot(x_new, radius_function(x_new),'#0504aa', alpha = .8, label = 'Initial Envelope Fraction of 5%')
                        if (enFrac == .1):
                            plt.plot(x_new, radius_function(x_new),'#0504aa', alpha = .6, label = 'Initial Envelope Fraction of 10%')
                        if (enFrac == .25):
                            plt.plot(x_new, radius_function(x_new),'#0504aa', alpha = .4, label = 'Initial Envelope Fraction of 25%')
                        if (enFrac == .5):
                            plt.plot(x_new, radius_function(x_new),'#0504aa', alpha = .2, label = 'Initial Envelope Fraction of 50%')
                            
                        
enFracList=[.01,.05,.1,.25,.5]
yList = [.18,.20,.22,.24,.26,.28]
                        
plt.plot(core_domain, core_radius_function(core_domain), 'k--', label = '')                           
plt.xlabel('Planet Mass $M_\oplus$')
plt.ylabel('Final Radius at 10 Gigayears $R_\oplus$')
plt.title('Mass Radius Relationship')
plt.axis([5, 15, 0, 7.5])
plt.legend(loc = 1)
#plt.grid(True)
#plt.savefig('/Users/isaacmalsky/Desktop/Y_.80.png',dpi=1000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
###############################################
########    Orbital Sep vs Hydrogen   #########
###############################################


import numpy as np
import matplotlib.pyplot as plt
from scipy import loadtxt, optimize
import os
import sys
import os.path
import os.path
import shutil
# %matplotlib notebook
from scipy import loadtxt, optimize
from collections import defaultdict
from scipy.interpolate import interp1d

mpList=[22.2]
enFracList=[.04]
entropyList=[8.0]
yList = [.18,.24,.30]
zList = [.02]
orbitalList=[.05,.06,.07,.08,.09,.10,.15,.25,.50,1.0]


#Iterate again over all the files
numlogs = 0
base_path = "/Users/mmalsky/Desktop/FluxLogs/"
mass_rad_dict = {}
for a in range (0 ,len(mpList)):
    mp = mpList[a]
    for b in range (0 ,len(entropyList)):
        entropy = entropyList[b]
        for c in range (0 ,len(yList)):
            yfrac = yList[c]
            for d in range (0 ,len(zList)):
                zfrac = zList[d]
                for e in range (0 ,len(enFracList)):
                    enFrac = enFracList[e]
                    
                    
                    orb_list = []
                    hydrogen_list = [] 
                    helium_list = []
                    
                    for f in range(len(orbitalList)):
                        myfile = ''
                        orb_sep = orbitalList[f]

                        extension = "{}_{}_{}_{}_{}_{}".format(mp,enFrac,entropy,yfrac,zfrac,orb_sep)
                        myfile = base_path + extension

                        if (os.path.isfile(myfile)):
                            age, hydrogen, helium = loadtxt(myfile, unpack=True, skiprows =6, usecols=[0,12,14])
                            array_type = str(type(age))
                            
                            if (array_type == "<type 'numpy.ndarray'>"):
                                if (max(age) > 9):
                                    print ('hmm')
                                    mass_rad_dict[myfile] = [age,hydrogen]
                                    orb_list.append(orb_sep)
                                    hydrogen_list.append(hydrogen[-1])
                                    helium_list.append(helium[-1])

                    if (len(orb_list) > 2):
                        h_function = interp1d(orb_list,hydrogen_list, kind='quadratic', fill_value = 'extrapolate')
                        he_function = interp1d(orb_list,helium_list, kind='quadratic', fill_value = 'extrapolate')
                        print (orb_list)
                        
                        
                        
                        x_new = np.linspace(min(orb_list), max(orb_list), num=5000, endpoint=True)
                        extra = np.linspace(0, .5, num=5000, endpoint=True)
                        
                        plt.plot(extra,h_function(extra), 'k:', label = '')
                        plt.plot(x_new,h_function(x_new), 'b', label = '')
                        
                        if yfrac == .18:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'b', label = 'Initial He of .18')
                        if yfrac == .24:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'g', label = 'Initial He of .24')
                        if yfrac == .30:
                            plt.plot(extra,h_function(extra), 'k:', label = '')
                            plt.plot(x_new,h_function(x_new), 'y', label = 'Initial He of .30')
                        
                        #plt.plot(extra, he_function(extra), 'k:', label = '')
                        #plt.plot(x_new, he_function(x_new), 'g', label = '')
                        
                    
                        #plt.plot(extra, (1 - he_function(extra) - h_function(extra)), 'r', label = '')
                        #ax1.fill_between(extra, h_function(extra), facecolor="#CC6666", alpha=.7)
                        
                            
                        
                        
                     
                        
plt.xlabel('Orbital Separation')
plt.ylabel('Fractional Abundance of Hydrogen in the Envelope')
plt.title('Atmospheric Escape')
plt.axis([0, .15, 0, 1])   
plt.legend()
                                    
plt.savefig('/Users/mmalsky/Desktop/OrbitalVariation.png',dpi=1000)
# Out:
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# [0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.15, 0.25, 0.5, 1.0]
# <img src="data:image/png;base64,..." width="640">
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# [0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.15, 0.25, 0.5, 1.0]
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# [0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.15, 0.25, 0.5, 1.0]
